# %%
Bài 1:
import torch

a = torch.tensor(
    [[1, 2, 3],
     [4, 5, 6]],
    dtype=torch.int32
)

print(a)

print("Kích thước:", a.shape)
print("Số chiều:", a.ndim)
print("Kiểu dữ liệu:", a.dtype)
Bài 2:
import torch

a = torch.rand(3, 4)
b = torch.randn(3, 4)
c = torch.zeros(2, 3)
d = torch.ones(2, 3)
e = torch.eye(4)

print("Tensor rand:")
print(a)

print("\nTensor randn:")
print(b)

print("\nTensor zeros:")
print(c)

print("\nTensor ones:")
print(d)

print("\nMa trận đơn vị:")
print(e)

# Tensor 5 x 5 toàn số 10
f = torch.full((5, 5), 10)

print("\nTensor 5 x 5 toàn số 10:")
print(f)
Bài 3:
import torch

a = torch.zeros(2, 3, 4)

print("Tensor:")
print(a)

print("Shape:", a.shape)
print("Size:", a.size())
print("Number of dimensions:", a.ndim)
print("Data type:", a.dtype)
Bài 4:
import torch
a = torch.randn(3, 4, 5)
print("Original tensor:")
print(a)
print("\nTensor a[1]:")
print(a[1])
print("\nTensor a[1:, 2:4]:")
print(a[1:, 2:4])
Bài 5:
import torch

a = torch.randn(3, 4)

print("Original:")
print(a)
print("Shape:", a.shape)
print("Số phần tử:", a.numel())

print("\nFlatten:")
b = a.ravel()
print(b)
print("Shape:", b.shape)
print("Số phần tử:", b.numel())

print("\nReshape to 3 x 2 x 2:")
c = a.reshape(3, 2, 2)
print(c)
print("Shape:", c.shape)
print("Số phần tử:", c.numel())

print("\nReshape to 2 x 6:")
d = a.reshape(2, 6)
print(d)
print("Shape:", d.shape)
print("Số phần tử:", d.numel())
Bài 6:

import torch
a = torch.randn(2, 3)
b = torch.randn(2, 3)
print("a:")
print(a)
print("b:")
print(b)


print("\na + b:")
print(a + b)
print("\na / b:")
print(a / b)
print("\na^2:")
print(a ** 2)
print("\nMatrix multiplication:")
print(a @ b.T)
Bài 7:
import torch

a = torch.randn(3, 4)

print("Tensor:")
print(a)

print("\n--- DIM = 0 ---")

print("Mean:")
print(torch.mean(a, dim=0))

print("Standard deviation:")
print(torch.std(a, dim=0))

print("Cumulative sum:")
print(torch.cumsum(a, dim=0))


print("\n--- DIM = 1 ---")

print("Mean:")
print(torch.mean(a, dim=1))

print("Standard deviation:")
print(torch.std(a, dim=1))

print("Cumulative sum:")
print(torch.cumsum(a, dim=1))
Bài 8:
import torch

x = torch.tensor(
    3.6,
    requires_grad=True
)

y = x * x

y.backward()

print("x =", x)
print("y =", y)
print("x.grad =", x.grad)
Bài 9:
import numpy as np
import torch
polynomial = np.poly1d([1, 2, 3])
N = 20
X = np.random.randn(N, 1) * 5
Y = polynomial(X)
XX = np.hstack([
X * X,
X,
np.ones_like(X)
])
w = torch.randn(3, 1, requires_grad=True)
x = torch.tensor(XX, dtype=torch.float32)
y = torch.tensor(Y, dtype=torch.float32)
optimizer = torch.optim.NAdam([w], lr=0.01)
print("Initial coefficients:")
print(w)
for epoch in range(1000):
    optimizer.zero_grad()
    y_pred = x @ w
    mse = torch.mean(torch.square(y - y_pred))
    mse.backward()
    optimizer.step()
print("Learned coefficients:")
print(w)
Bài 10:
 import random
import torch
A = torch.tensor(random.random(), requires_grad=True)
B = torch.tensor(random.random(), requires_grad=True)
C = torch.tensor(random.random(), requires_grad=True)
D = torch.tensor(random.random(), requires_grad=True)
EPOCHS = 2000
optimizer = torch.optim.NAdam([A, B, C, D], lr=0.01)
for _ in range(EPOCHS):
    y1 = A + B - 9
    y2 = C - D - 1
    y3 = A + C - 8
    y4 = B - D - 2
    sqerr = y1*y1 + y2*y2 + y3*y3 + y4*y4
    optimizer.zero_grad()
    sqerr.backward()
    optimizer.step()
print("A =", A)
print("B =", B)
print("C =", C)
print("D =", D)
Bài 11:
import numpy as np
import torch

# ==================================================
# PHAN 1: Tao Tensor X va reshape
# ==================================================

X = torch.arange(24)

print("=== PHAN 1 ===")
print("X:", X)
print("So phan tu:", X.numel())

print("\nX - 4 x 6:")
print(X.reshape(4, 6))

print("\nX - 2 x 12:")
print(X.reshape(2, 12))

print("\nX - 2 x 3 x 4:")
print(X.reshape(2, 3, 4))


# ==================================================
# PHAN 2: Phep toan Tensor
# ==================================================

A = torch.randn(3, 4)
B = torch.randn(3, 4)

print("\n=== PHAN 2 ===")
print("A:")
print(A)

print("\nB:")
print(B)

print("\nA + B:")
print(A + B)

print("\nA * B:")
print(A * B)

print("\nA / B:")
print(A / B)

print("\nTrung binh theo cot:")
print(torch.mean(A, dim=0))

print("\nDo lech chuan theo cot:")
print(torch.std(A, dim=0))


# ==================================================
# PHAN 3: Autograd
# ==================================================

print("\n=== PHAN 3 ===")

x = torch.tensor(2.0, requires_grad=True)

y = 2 * x**2 + 5 * x + 3

y.backward()

print("x =", x)
print("y =", y)
print("dy/dx bang Autograd =", x.grad)

# Tinh thu cong
manual_gradient = 4 * 2 + 5

print("dy/dx tinh thu cong =", manual_gradient)


# ==================================================
# PHAN 4: Gradient Descent tim he so da thuc
# ==================================================

print("\n=== PHAN 4 ===")

# Da thuc: y = 2x^2 - 3x + 5
polynomial = np.poly1d([2, -3, 5])

N = 20

X = np.random.randn(N, 1) * 5

Y = polynomial(X)

XX = np.hstack([
    X * X,
    X,
    np.ones_like(X)
])

w = torch.randn(3, 1, requires_grad=True)

x_data = torch.tensor(XX, dtype=torch.float32)
y_data = torch.tensor(Y, dtype=torch.float32)

optimizer = torch.optim.NAdam([w], lr=0.01)

print("He so ban dau:")
print(w)

for epoch in range(1000):

    optimizer.zero_grad()

    y_pred = x_data @ w

    mse = torch.mean(torch.square(y_data - y_pred))

    mse.backward()

    optimizer.step()

print("\nHe so hoc duoc:")
print(w)

print("\nHe so muc tieu: [2, -3, 5]")
